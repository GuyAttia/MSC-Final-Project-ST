# %% [markdown]
# # Imports

# %%
from os import path, listdir
from copy import deepcopy
import stlearn as st
import numpy as np
import pandas as pd
import seaborn as sns
import torch
import matplotlib.pyplot as plt
import cv2
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OrdinalEncoder
from torch import tensor
from torch.utils.data import DataLoader, Dataset
import torch.optim as optim

# %load_ext autoreload
# %autoreload 2

from scanpy_stlearn_loaders import StlearnLoader
import trainer as trainer
from data import get_data
from models import get_model
from tester import tester
from loss import *
from results_analysis import *

# %%
plt.rcParams.update({'font.size': 12})
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('Using device:', device)
# Out:
# Using device: cuda

# %% [markdown]
# # Load Data

# %%
dataset_name = 'Visium_Mouse_Olfactory_Bulb'

# %% [markdown]
# ## Genes-Spots Expression Values

# %%
obj = StlearnLoader().load_local_visum(path=path.join('/', 'data', dataset_name),
                                      count_file='filtered_feature_bc_matrix.h5')
x = obj.X.toarray()
n_spots, n_genes = x.shape
print(f'# spots: {n_spots} | # genes: {n_genes}')
obj
# Out:
# /usr/local/lib/python3.8/site-packages/anndata/_core/anndata.py:1830: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# # spots: 1185 | # genes: 32285
# AnnData object with n_obs × n_vars = 1185 × 32285
#     obs: 'in_tissue', 'array_row', 'array_col', 'imagecol', 'imagerow'
#     var: 'gene_ids', 'feature_types', 'genome'
#     uns: 'spatial'
#     obsm: 'spatial'

# %% [markdown]
# # Filter Genes
# - min_cells = Keep genes with at least X spots with non zero expression (x[spot, gene] > 0)
# - min_counts = Keep genes with at least X expressions (sum of expression over all spots) (sum(x[:, gene]) > X)

# %%
# Keep genes with at least 15% non zero spots
min_cells = int(n_spots * 0.985)
print(f'Keep genes with at least {min_cells} non zero spots')
st.pp.filter_genes(obj, min_cells=min_cells)
x = obj.X.toarray()
n_spots, n_genes = x.shape
print(f'# spots: {n_spots} | # genes: {n_genes}')
# Out:
# Keep genes with at least 1167 non zero spots
# # spots: 1185 | # genes: 96

# %%
min_counts = 10
print(f'Keep genes with total expression of at least {min_counts} over all spots')
st.pp.filter_genes(obj, min_counts=min_counts)
x = obj.X.toarray()
n_spots, n_genes = x.shape
print(f'# spots: {n_spots} | # genes: {n_genes}')
# Out:
# Keep genes with total expression of at least 10 over all spots
# # spots: 1185 | # genes: 96

# %% [markdown]
# ## Log Transform Expressions

# %%
x = np.log(x+1)

# %% [markdown]
# # Generate Expression DF

# %% [markdown]
# ## Transfer Matrix to DF

# %%
spots_values = obj.obs.index.values
genes_values = obj.var.index.values
df_expressions_matrix = pd.DataFrame(x, columns=genes_values, index=spots_values)
df_expressions = df_expressions_matrix.stack().reset_index()
df_expressions.columns = ['spot', 'gene', 'expression']
print(f'shape: {df_expressions.shape}')
display(df_expressions['expression'].describe())
df_expressions.head()
# Out:
# shape: (113760, 3)
# count    113760.000000
# mean          3.175853
# std           1.138551
# min           0.000000
# 25%           2.484907
# 50%           3.178054
# 75%           3.806663
# max           7.599401
# Name: expression, dtype: float64
#                  spot    gene  expression
# 0  AAACAAGTATCTCCCA-1  Rpl37a    0.000000
# 1  AAACAAGTATCTCCCA-1     Dbi    0.000000
# 2  AAACAAGTATCTCCCA-1    Glul    0.693147
# 3  AAACAAGTATCTCCCA-1  Atp1a2    1.098612
# 4  AAACAAGTATCTCCCA-1   Ptgds    2.197225

# %%
plt.figure(figsize=(15, 5))
df_expressions.loc[df_expressions['expression'] < 10, 'expression'].plot.hist(bins=10)
plt.title('Gene-Spot expression histogram')
plt.show()

# %% [markdown]
# ## Encode Genes and Spots

# %%
# Ordinal encoding the genes and spots for supported type
oe_genes = OrdinalEncoder()
df_expressions[['gene']] = oe_genes.fit_transform(df_expressions[['gene']].values)
oe_spots = OrdinalEncoder()
df_expressions[['spot']] = oe_spots.fit_transform(df_expressions[['spot']].values)

df_expressions[['spot', 'gene']] = df_expressions[['spot', 'gene']].astype(int)
df_expressions.head()
# Out:
#    spot  gene  expression
# 0     0    56    0.000000
# 1     0    15    0.000000
# 2     0    23    0.693147
# 3     0     4    1.098612
# 4     0    36    2.197225

# %% [markdown]
# # Train Test Split

# %%
def plot_datasets_distribution(df_train, df_valid, df_test):
    print(f'Split to train, valid, and test:\nTrain shape:{df_train.shape}\nValid shape:{df_valid.shape}\nTest shape:{df_test.shape}')
    f, axs = plt.subplots(1, 3, figsize=(19, 5), sharey=True, sharex=True)
    df_train.loc[df_train['expression'] < 10, 'expression'].value_counts(normalize=True).sort_index().plot.bar(ax=axs[0])
    df_valid.loc[df_valid['expression'] < 10, 'expression'].value_counts(normalize=True).sort_index().plot.bar(ax=axs[1])
    df_test.loc[df_test['expression'] < 10, 'expression'].value_counts(normalize=True).sort_index().plot.bar(ax=axs[2])
    axs[0].set_title(f'Train Expression Dist | Avg Expression: {df_train["expression"].mean():.2f}')
    axs[1].set_title(f'Valid Expression Dist | Avg Expression: {df_valid["expression"].mean():.2f}')
    axs[2].set_title(f'Test Expression Dist | Avg Expression: {df_test["expression"].mean():.2f}')
    plt.show()

# %% [markdown]
# ## Normal Random

# %%
df_train, df_test = train_test_split(df_expressions, test_size=0.10)
df_train, df_valid = train_test_split(df_train, test_size=0.10)

# %%
plot_datasets_distribution(df_train, df_valid, df_test)
print('We can see that the train, valid and test datasets share the same expression distribution')
# Out:
# Split to train, valid, and test:
# Train shape:(92145, 3)
# Valid shape:(10239, 3)
# Test shape:(11376, 3)
# We can see that the train, valid and test datasets share the same expression distribution

# %% [markdown]
# # Create Pytorch Data Loaders

# %%
batch_size = 128

# %% [markdown]
# ## Generate DataSets

# %%
class ExpressionDataset(Dataset):
    """
    Generate expression dataset to use in the our models, where each sample should be a tuple of (gene, spot, expression)
    """

    def __init__(self, df, device):
        self.num_samples = len(df)
        self.genes = tensor(df['gene'].values).to(device)
        self.spots = tensor(df['spot'].values).to(device)
        self.labels = tensor(df['expression'].values)
        self.num_genes = df['gene'].max()
        self.num_spots = df['spot'].max()

    def __getitem__(self, index):
        gene = self.genes[index]
        spot = self.spots[index]
        label = self.labels[index].item()
        return gene, spot, label

    def __len__(self):
        return self.num_samples

    def get_all_data(self):
        return self.genes, self.spots, self.labels

# %%
ds_train = ExpressionDataset(df=df_train, device=device)
ds_valid = ExpressionDataset(df=df_valid, device=device)
ds_test = ExpressionDataset(df=df_test, device=device)

# %% [markdown]
# ## DataSets to DataLoaders

# %%
dl_train = DataLoader(dataset=ds_train, batch_size=batch_size, shuffle=True)
dl_valid = DataLoader(dataset=ds_valid, batch_size=batch_size, shuffle=True)
dl_test = DataLoader(dataset=ds_test, batch_size=batch_size, shuffle=True)

# %% [markdown]
# # Load Model

# %%
dl_train_exp = dl_train
dl_valid_exp = dl_valid
dl_test_exp = dl_test

# %%
model_name='NMF'
params = {
    'learning_rate': 0.1,
    'optimizer': "SGD",
    'latent_dim': 40,
    'batch_size': batch_size
}

# %%
model = get_model(model_name=model_name, params=params, dl_train=dl_train_exp)

# %% [markdown]
# # Train Model

# %%
max_epochs = 300
early_stopping = 15

# %% [markdown]
# ## Load Optimizer

# %%
optimizer = getattr(optim, params['optimizer'])(model.parameters(), lr=params['learning_rate'])
criterion = NON_ZERO_RMSELoss()

# %% [markdown]
# ## Train

# %%
model, valid_loss = trainer.trainer(
    model=model, 
    optimizer=optimizer, 
    criterion=criterion,
    max_epochs=max_epochs, 
    early_stopping=early_stopping, 
    dl_train=dl_train_exp, 
    dl_test=dl_valid_exp, 
    device=device, 
    dataset_name=dataset_name, 
    model_name=model_name
)
# Out:
# 2022-08-27 07:03:14.141896: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/lib/python3.8/site-packages/cv2/../../lib64:
# 2022-08-27 07:03:14.141944: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# Training Results - Epoch[1] Avg loss: 6.42
# Validation Results - Epoch[1] Avg loss: 6.48
# Training Results - Epoch[2] Avg loss: 5.84
# Validation Results - Epoch[2] Avg loss: 5.96
# Training Results - Epoch[3] Avg loss: 5.33
# Validation Results - Epoch[3] Avg loss: 5.49
# Training Results - Epoch[4] Avg loss: 4.90
# Validation Results - Epoch[4] Avg loss: 5.08
# Training Results - Epoch[5] Avg loss: 4.53
# Validation Results - Epoch[5] Avg loss: 4.73
# Training Results - Epoch[6] Avg loss: 4.22
# Validation Results - Epoch[6] Avg loss: 4.43
# Training Results - Epoch[7] Avg loss: 3.98
# Validation Results - Epoch[7] Avg loss: 4.19
# Training Results - Epoch[8] Avg loss: 3.78
# Validation Results - Epoch[8] Avg loss: 3.99
# Training Results - Epoch[9] Avg loss: 3.61
# Validation Results - Epoch[9] Avg loss: 3.83
# Training Results - Epoch[10] Avg loss: 3.48
# Validation Results - Epoch[10] Avg loss: 3.69
# Training Results - Epoch[11] Avg loss: 3.37
# Validation Results - Epoch[11] Avg loss: 3.57
# Training Results - Epoch[12] Avg loss: 3.26
# Validation Results - Epoch[12] Avg loss: 3.46
# Training Results - Epoch[13] Avg loss: 3.15
# Validation Results - Epoch[13] Avg loss: 3.35
# Training Results - Epoch[14] Avg loss: 3.04
# Validation Results - Epoch[14] Avg loss: 3.23
# Training Results - Epoch[15] Avg loss: 2.91
# Validation Results - Epoch[15] Avg loss: 3.10
# Training Results - Epoch[16] Avg loss: 2.75
# Validation Results - Epoch[16] Avg loss: 2.94
# Training Results - Epoch[17] Avg loss: 2.57
# Validation Results - Epoch[17] Avg loss: 2.75
# Training Results - Epoch[18] Avg loss: 2.34
# Validation Results - Epoch[18] Avg loss: 2.52
# Training Results - Epoch[19] Avg loss: 2.08
# Validation Results - Epoch[19] Avg loss: 2.24
# Training Results - Epoch[20] Avg loss: 1.77
# Validation Results - Epoch[20] Avg loss: 1.92
# Training Results - Epoch[21] Avg loss: 1.43
# Validation Results - Epoch[21] Avg loss: 1.56
# Training Results - Epoch[22] Avg loss: 1.07
# Validation Results - Epoch[22] Avg loss: 1.18
# Training Results - Epoch[23] Avg loss: 0.74
# Validation Results - Epoch[23] Avg loss: 0.82
# Training Results - Epoch[24] Avg loss: 0.52
# Validation Results - Epoch[24] Avg loss: 0.56
# Training Results - Epoch[25] Avg loss: 0.44
# Validation Results - Epoch[25] Avg loss: 0.47
# Training Results - Epoch[26] Avg loss: 0.43
# Validation Results - Epoch[26] Avg loss: 0.45
# Training Results - Epoch[27] Avg loss: 0.43
# Validation Results - Epoch[27] Avg loss: 0.44
# Training Results - Epoch[28] Avg loss: 0.43
# Validation Results - Epoch[28] Avg loss: 0.44
# Training Results - Epoch[29] Avg loss: 0.43
# Validation Results - Epoch[29] Avg loss: 0.44
# Training Results - Epoch[30] Avg loss: 0.43
# Validation Results - Epoch[30] Avg loss: 0.44
# Training Results - Epoch[31] Avg loss: 0.43
# Validation Results - Epoch[31] Avg loss: 0.44
# Training Results - Epoch[32] Avg loss: 0.43
# Validation Results - Epoch[32] Avg loss: 0.44
# Training Results - Epoch[33] Avg loss: 0.43
# Validation Results - Epoch[33] Avg loss: 0.44
# Training Results - Epoch[34] Avg loss: 0.43
# Validation Results - Epoch[34] Avg loss: 0.44
# Training Results - Epoch[35] Avg loss: 0.43
# Validation Results - Epoch[35] Avg loss: 0.44
# Training Results - Epoch[36] Avg loss: 0.43
# Validation Results - Epoch[36] Avg loss: 0.44
# Training Results - Epoch[37] Avg loss: 0.43
# Validation Results - Epoch[37] Avg loss: 0.44
# Training Results - Epoch[38] Avg loss: 0.43
# Validation Results - Epoch[38] Avg loss: 0.44
# Training Results - Epoch[39] Avg loss: 0.43
# Validation Results - Epoch[39] Avg loss: 0.44
# Training Results - Epoch[40] Avg loss: 0.43
# Validation Results - Epoch[40] Avg loss: 0.44
# Training Results - Epoch[41] Avg loss: 0.42
# Validation Results - Epoch[41] Avg loss: 0.44
# Training Results - Epoch[42] Avg loss: 0.42
# Validation Results - Epoch[42] Avg loss: 0.44
# Training Results - Epoch[43] Avg loss: 0.42
# Validation Results - Epoch[43] Avg loss: 0.44
# Training Results - Epoch[44] Avg loss: 0.42
# Validation Results - Epoch[44] Avg loss: 0.44
# Training Results - Epoch[45] Avg loss: 0.42
# Validation Results - Epoch[45] Avg loss: 0.44
# Training Results - Epoch[46] Avg loss: 0.42
# Validation Results - Epoch[46] Avg loss: 0.44
# Training Results - Epoch[47] Avg loss: 0.42
# Validation Results - Epoch[47] Avg loss: 0.44
# Training Results - Epoch[48] Avg loss: 0.42
# Validation Results - Epoch[48] Avg loss: 0.44
# Training Results - Epoch[49] Avg loss: 0.42
# Validation Results - Epoch[49] Avg loss: 0.44
# Training Results - Epoch[50] Avg loss: 0.42
# Validation Results - Epoch[50] Avg loss: 0.44
# Training Results - Epoch[51] Avg loss: 0.42
# Validation Results - Epoch[51] Avg loss: 0.44
# Training Results - Epoch[52] Avg loss: 0.42
# Validation Results - Epoch[52] Avg loss: 0.44
# Training Results - Epoch[53] Avg loss: 0.42
# Validation Results - Epoch[53] Avg loss: 0.44
# Training Results - Epoch[54] Avg loss: 0.42
# Validation Results - Epoch[54] Avg loss: 0.44
# Training Results - Epoch[55] Avg loss: 0.42
# Validation Results - Epoch[55] Avg loss: 0.44
# Training Results - Epoch[56] Avg loss: 0.42
# Validation Results - Epoch[56] Avg loss: 0.44
# Training Results - Epoch[57] Avg loss: 0.42
# Validation Results - Epoch[57] Avg loss: 0.44
# Training Results - Epoch[58] Avg loss: 0.42
# Validation Results - Epoch[58] Avg loss: 0.44
# Training Results - Epoch[59] Avg loss: 0.42
# Validation Results - Epoch[59] Avg loss: 0.44
# Training Results - Epoch[60] Avg loss: 0.42
# Validation Results - Epoch[60] Avg loss: 0.44
# Training Results - Epoch[61] Avg loss: 0.42
# Validation Results - Epoch[61] Avg loss: 0.44
# Training Results - Epoch[62] Avg loss: 0.42
# Validation Results - Epoch[62] Avg loss: 0.44
# Training Results - Epoch[63] Avg loss: 0.42
# Validation Results - Epoch[63] Avg loss: 0.44
# Training Results - Epoch[64] Avg loss: 0.42
# Validation Results - Epoch[64] Avg loss: 0.44
# Training Results - Epoch[65] Avg loss: 0.42
# Validation Results - Epoch[65] Avg loss: 0.44
# Training Results - Epoch[66] Avg loss: 0.42
# Validation Results - Epoch[66] Avg loss: 0.44
# Training Results - Epoch[67] Avg loss: 0.42
# Validation Results - Epoch[67] Avg loss: 0.44
# Training Results - Epoch[68] Avg loss: 0.42
# Validation Results - Epoch[68] Avg loss: 0.44
# Training Results - Epoch[69] Avg loss: 0.42
# Validation Results - Epoch[69] Avg loss: 0.44
# Training Results - Epoch[70] Avg loss: 0.42
# Validation Results - Epoch[70] Avg loss: 0.44
# Training Results - Epoch[71] Avg loss: 0.42
# Validation Results - Epoch[71] Avg loss: 0.43
# Training Results - Epoch[72] Avg loss: 0.42
# Validation Results - Epoch[72] Avg loss: 0.44
# Training Results - Epoch[73] Avg loss: 0.42
# Validation Results - Epoch[73] Avg loss: 0.44
# Training Results - Epoch[74] Avg loss: 0.42
# Validation Results - Epoch[74] Avg loss: 0.44
# Training Results - Epoch[75] Avg loss: 0.42
# Validation Results - Epoch[75] Avg loss: 0.44
# Training Results - Epoch[76] Avg loss: 0.42
# Validation Results - Epoch[76] Avg loss: 0.43
# Training Results - Epoch[77] Avg loss: 0.42
# Validation Results - Epoch[77] Avg loss: 0.43
# Training Results - Epoch[78] Avg loss: 0.41
# Validation Results - Epoch[78] Avg loss: 0.43
# Training Results - Epoch[79] Avg loss: 0.41
# Validation Results - Epoch[79] Avg loss: 0.43
# Training Results - Epoch[80] Avg loss: 0.41
# Validation Results - Epoch[80] Avg loss: 0.43
# Training Results - Epoch[81] Avg loss: 0.41
# Validation Results - Epoch[81] Avg loss: 0.43
# Training Results - Epoch[82] Avg loss: 0.41
# Validation Results - Epoch[82] Avg loss: 0.43
# Training Results - Epoch[83] Avg loss: 0.41
# Validation Results - Epoch[83] Avg loss: 0.43
# Training Results - Epoch[84] Avg loss: 0.41
# Validation Results - Epoch[84] Avg loss: 0.43
# Training Results - Epoch[85] Avg loss: 0.41
# Validation Results - Epoch[85] Avg loss: 0.43
# Training Results - Epoch[86] Avg loss: 0.41
# Validation Results - Epoch[86] Avg loss: 0.43
# Training Results - Epoch[87] Avg loss: 0.41
# Validation Results - Epoch[87] Avg loss: 0.43
# Training Results - Epoch[88] Avg loss: 0.41
# Validation Results - Epoch[88] Avg loss: 0.43
# Training Results - Epoch[89] Avg loss: 0.41
# Validation Results - Epoch[89] Avg loss: 0.43
# Training Results - Epoch[90] Avg loss: 0.41
# Validation Results - Epoch[90] Avg loss: 0.43
# Training Results - Epoch[91] Avg loss: 0.41
# Validation Results - Epoch[91] Avg loss: 0.43
# Training Results - Epoch[92] Avg loss: 0.41
# Validation Results - Epoch[92] Avg loss: 0.43
# Training Results - Epoch[93] Avg loss: 0.41
# Validation Results - Epoch[93] Avg loss: 0.43
# Training Results - Epoch[94] Avg loss: 0.41
# Validation Results - Epoch[94] Avg loss: 0.43
# Training Results - Epoch[95] Avg loss: 0.41
# Validation Results - Epoch[95] Avg loss: 0.43
# Training Results - Epoch[96] Avg loss: 0.41
# Validation Results - Epoch[96] Avg loss: 0.42
# Training Results - Epoch[97] Avg loss: 0.41
# Validation Results - Epoch[97] Avg loss: 0.42
# Training Results - Epoch[98] Avg loss: 0.40
# Validation Results - Epoch[98] Avg loss: 0.42
# Training Results - Epoch[99] Avg loss: 0.40
# Validation Results - Epoch[99] Avg loss: 0.42
# Training Results - Epoch[100] Avg loss: 0.40
# Validation Results - Epoch[100] Avg loss: 0.42
# Training Results - Epoch[101] Avg loss: 0.40
# Validation Results - Epoch[101] Avg loss: 0.42
# Training Results - Epoch[102] Avg loss: 0.40
# Validation Results - Epoch[102] Avg loss: 0.42
# Training Results - Epoch[103] Avg loss: 0.40
# Validation Results - Epoch[103] Avg loss: 0.42
# Training Results - Epoch[104] Avg loss: 0.40
# Validation Results - Epoch[104] Avg loss: 0.42
# Training Results - Epoch[105] Avg loss: 0.40
# Validation Results - Epoch[105] Avg loss: 0.42
# Training Results - Epoch[106] Avg loss: 0.40
# Validation Results - Epoch[106] Avg loss: 0.42
# Training Results - Epoch[107] Avg loss: 0.40
# Validation Results - Epoch[107] Avg loss: 0.42
# Training Results - Epoch[108] Avg loss: 0.40
# Validation Results - Epoch[108] Avg loss: 0.42
# Training Results - Epoch[109] Avg loss: 0.40
# Validation Results - Epoch[109] Avg loss: 0.42
# Training Results - Epoch[110] Avg loss: 0.40
# Validation Results - Epoch[110] Avg loss: 0.42
# Training Results - Epoch[111] Avg loss: 0.39
# Validation Results - Epoch[111] Avg loss: 0.42
# Training Results - Epoch[112] Avg loss: 0.39
# Validation Results - Epoch[112] Avg loss: 0.42
# Training Results - Epoch[113] Avg loss: 0.39
# Validation Results - Epoch[113] Avg loss: 0.41
# Training Results - Epoch[114] Avg loss: 0.39
# Validation Results - Epoch[114] Avg loss: 0.41
# Training Results - Epoch[115] Avg loss: 0.39
# Validation Results - Epoch[115] Avg loss: 0.41
# Training Results - Epoch[116] Avg loss: 0.39
# Validation Results - Epoch[116] Avg loss: 0.41
# Training Results - Epoch[117] Avg loss: 0.39
# Validation Results - Epoch[117] Avg loss: 0.41
# Training Results - Epoch[118] Avg loss: 0.39
# Validation Results - Epoch[118] Avg loss: 0.41
# Training Results - Epoch[119] Avg loss: 0.39
# Validation Results - Epoch[119] Avg loss: 0.41
# Training Results - Epoch[120] Avg loss: 0.39
# Validation Results - Epoch[120] Avg loss: 0.41
# Training Results - Epoch[121] Avg loss: 0.39
# Validation Results - Epoch[121] Avg loss: 0.41
# Training Results - Epoch[122] Avg loss: 0.38
# Validation Results - Epoch[122] Avg loss: 0.41
# Training Results - Epoch[123] Avg loss: 0.38
# Validation Results - Epoch[123] Avg loss: 0.40
# Training Results - Epoch[124] Avg loss: 0.38
# Validation Results - Epoch[124] Avg loss: 0.40
# Training Results - Epoch[125] Avg loss: 0.38
# Validation Results - Epoch[125] Avg loss: 0.40
# Training Results - Epoch[126] Avg loss: 0.38
# Validation Results - Epoch[126] Avg loss: 0.40
# Training Results - Epoch[127] Avg loss: 0.38
# Validation Results - Epoch[127] Avg loss: 0.40
# Training Results - Epoch[128] Avg loss: 0.38
# Validation Results - Epoch[128] Avg loss: 0.40
# Training Results - Epoch[129] Avg loss: 0.38
# Validation Results - Epoch[129] Avg loss: 0.40
# Training Results - Epoch[130] Avg loss: 0.38
# Validation Results - Epoch[130] Avg loss: 0.40
# Training Results - Epoch[131] Avg loss: 0.38
# Validation Results - Epoch[131] Avg loss: 0.40
# Training Results - Epoch[132] Avg loss: 0.38
# Validation Results - Epoch[132] Avg loss: 0.40
# Training Results - Epoch[133] Avg loss: 0.37
# Validation Results - Epoch[133] Avg loss: 0.40
# Training Results - Epoch[134] Avg loss: 0.37
# Validation Results - Epoch[134] Avg loss: 0.39
# Training Results - Epoch[135] Avg loss: 0.37
# Validation Results - Epoch[135] Avg loss: 0.39
# Training Results - Epoch[136] Avg loss: 0.37
# Validation Results - Epoch[136] Avg loss: 0.39
# Training Results - Epoch[137] Avg loss: 0.37
# Validation Results - Epoch[137] Avg loss: 0.39
# Training Results - Epoch[138] Avg loss: 0.37
# Validation Results - Epoch[138] Avg loss: 0.39
# Training Results - Epoch[139] Avg loss: 0.37
# Validation Results - Epoch[139] Avg loss: 0.39
# Training Results - Epoch[140] Avg loss: 0.37
# Validation Results - Epoch[140] Avg loss: 0.39
# Training Results - Epoch[141] Avg loss: 0.37
# Validation Results - Epoch[141] Avg loss: 0.39
# Training Results - Epoch[142] Avg loss: 0.36
# Validation Results - Epoch[142] Avg loss: 0.39
# Training Results - Epoch[143] Avg loss: 0.36
# Validation Results - Epoch[143] Avg loss: 0.39
# Training Results - Epoch[144] Avg loss: 0.36
# Validation Results - Epoch[144] Avg loss: 0.38
# Training Results - Epoch[145] Avg loss: 0.36
# Validation Results - Epoch[145] Avg loss: 0.38
# Training Results - Epoch[146] Avg loss: 0.36
# Validation Results - Epoch[146] Avg loss: 0.38
# Training Results - Epoch[147] Avg loss: 0.36
# Validation Results - Epoch[147] Avg loss: 0.38
# Training Results - Epoch[148] Avg loss: 0.36
# Validation Results - Epoch[148] Avg loss: 0.38
# Training Results - Epoch[149] Avg loss: 0.36
# Validation Results - Epoch[149] Avg loss: 0.38
# Training Results - Epoch[150] Avg loss: 0.36
# Validation Results - Epoch[150] Avg loss: 0.38
# Training Results - Epoch[151] Avg loss: 0.36
# Validation Results - Epoch[151] Avg loss: 0.38
# Training Results - Epoch[152] Avg loss: 0.35
# Validation Results - Epoch[152] Avg loss: 0.38
# Training Results - Epoch[153] Avg loss: 0.35
# Validation Results - Epoch[153] Avg loss: 0.38
# Training Results - Epoch[154] Avg loss: 0.35
# Validation Results - Epoch[154] Avg loss: 0.37
# Training Results - Epoch[155] Avg loss: 0.35
# Validation Results - Epoch[155] Avg loss: 0.37
# Training Results - Epoch[156] Avg loss: 0.35
# Validation Results - Epoch[156] Avg loss: 0.37
# Training Results - Epoch[157] Avg loss: 0.35
# Validation Results - Epoch[157] Avg loss: 0.37
# Training Results - Epoch[158] Avg loss: 0.35
# Validation Results - Epoch[158] Avg loss: 0.37
# Training Results - Epoch[159] Avg loss: 0.35
# Validation Results - Epoch[159] Avg loss: 0.37
# Training Results - Epoch[160] Avg loss: 0.35
# Validation Results - Epoch[160] Avg loss: 0.37
# Training Results - Epoch[161] Avg loss: 0.35
# Validation Results - Epoch[161] Avg loss: 0.37
# Training Results - Epoch[162] Avg loss: 0.35
# Validation Results - Epoch[162] Avg loss: 0.37
# Training Results - Epoch[163] Avg loss: 0.34
# Validation Results - Epoch[163] Avg loss: 0.37
# Training Results - Epoch[164] Avg loss: 0.34
# Validation Results - Epoch[164] Avg loss: 0.37
# Training Results - Epoch[165] Avg loss: 0.34
# Validation Results - Epoch[165] Avg loss: 0.36
# Training Results - Epoch[166] Avg loss: 0.34
# Validation Results - Epoch[166] Avg loss: 0.36
# Training Results - Epoch[167] Avg loss: 0.34
# Validation Results - Epoch[167] Avg loss: 0.36
# Training Results - Epoch[168] Avg loss: 0.34
# Validation Results - Epoch[168] Avg loss: 0.36
# Training Results - Epoch[169] Avg loss: 0.34
# Validation Results - Epoch[169] Avg loss: 0.36
# Training Results - Epoch[170] Avg loss: 0.34
# Validation Results - Epoch[170] Avg loss: 0.36
# Training Results - Epoch[171] Avg loss: 0.34
# Validation Results - Epoch[171] Avg loss: 0.36
# Training Results - Epoch[172] Avg loss: 0.34
# Validation Results - Epoch[172] Avg loss: 0.36
# Training Results - Epoch[173] Avg loss: 0.34
# Validation Results - Epoch[173] Avg loss: 0.36
# Training Results - Epoch[174] Avg loss: 0.34
# Validation Results - Epoch[174] Avg loss: 0.36
# Training Results - Epoch[175] Avg loss: 0.34
# Validation Results - Epoch[175] Avg loss: 0.36
# Training Results - Epoch[176] Avg loss: 0.33
# Validation Results - Epoch[176] Avg loss: 0.36
# Training Results - Epoch[177] Avg loss: 0.33
# Validation Results - Epoch[177] Avg loss: 0.35
# Training Results - Epoch[178] Avg loss: 0.33
# Validation Results - Epoch[178] Avg loss: 0.35
# Training Results - Epoch[179] Avg loss: 0.33
# Validation Results - Epoch[179] Avg loss: 0.35
# Training Results - Epoch[180] Avg loss: 0.33
# Validation Results - Epoch[180] Avg loss: 0.35
# Training Results - Epoch[181] Avg loss: 0.33
# Validation Results - Epoch[181] Avg loss: 0.35
# Training Results - Epoch[182] Avg loss: 0.33
# Validation Results - Epoch[182] Avg loss: 0.35
# Training Results - Epoch[183] Avg loss: 0.33
# Validation Results - Epoch[183] Avg loss: 0.35
# Training Results - Epoch[184] Avg loss: 0.33
# Validation Results - Epoch[184] Avg loss: 0.35
# Training Results - Epoch[185] Avg loss: 0.33
# Validation Results - Epoch[185] Avg loss: 0.35
# Training Results - Epoch[186] Avg loss: 0.33
# Validation Results - Epoch[186] Avg loss: 0.35
# Training Results - Epoch[187] Avg loss: 0.33
# Validation Results - Epoch[187] Avg loss: 0.35
# Training Results - Epoch[188] Avg loss: 0.33
# Validation Results - Epoch[188] Avg loss: 0.35
# Training Results - Epoch[189] Avg loss: 0.33
# Validation Results - Epoch[189] Avg loss: 0.35
# Training Results - Epoch[190] Avg loss: 0.33
# Validation Results - Epoch[190] Avg loss: 0.35
# Training Results - Epoch[191] Avg loss: 0.33
# Validation Results - Epoch[191] Avg loss: 0.35
# Training Results - Epoch[192] Avg loss: 0.33
# Validation Results - Epoch[192] Avg loss: 0.35
# Training Results - Epoch[193] Avg loss: 0.33
# Validation Results - Epoch[193] Avg loss: 0.35
# Training Results - Epoch[194] Avg loss: 0.33
# Validation Results - Epoch[194] Avg loss: 0.35
# Training Results - Epoch[195] Avg loss: 0.33
# Validation Results - Epoch[195] Avg loss: 0.35
# Training Results - Epoch[196] Avg loss: 0.32
# Validation Results - Epoch[196] Avg loss: 0.35
# Training Results - Epoch[197] Avg loss: 0.32
# Validation Results - Epoch[197] Avg loss: 0.34
# Training Results - Epoch[198] Avg loss: 0.32
# Validation Results - Epoch[198] Avg loss: 0.35
# Training Results - Epoch[199] Avg loss: 0.32
# Validation Results - Epoch[199] Avg loss: 0.34
# Training Results - Epoch[200] Avg loss: 0.32
# Validation Results - Epoch[200] Avg loss: 0.34
# Training Results - Epoch[201] Avg loss: 0.32
# Validation Results - Epoch[201] Avg loss: 0.34
# Training Results - Epoch[202] Avg loss: 0.32
# Validation Results - Epoch[202] Avg loss: 0.34
# Training Results - Epoch[203] Avg loss: 0.32
# Validation Results - Epoch[203] Avg loss: 0.34
# Training Results - Epoch[204] Avg loss: 0.32
# Validation Results - Epoch[204] Avg loss: 0.34
# Training Results - Epoch[205] Avg loss: 0.32
# Validation Results - Epoch[205] Avg loss: 0.34
# Training Results - Epoch[206] Avg loss: 0.32
# Validation Results - Epoch[206] Avg loss: 0.34
# Training Results - Epoch[207] Avg loss: 0.32
# Validation Results - Epoch[207] Avg loss: 0.34
# Training Results - Epoch[208] Avg loss: 0.32
# Validation Results - Epoch[208] Avg loss: 0.34
# Training Results - Epoch[209] Avg loss: 0.32
# Validation Results - Epoch[209] Avg loss: 0.34
# Training Results - Epoch[210] Avg loss: 0.32
# Validation Results - Epoch[210] Avg loss: 0.34
# Training Results - Epoch[211] Avg loss: 0.32
# Validation Results - Epoch[211] Avg loss: 0.34
# Training Results - Epoch[212] Avg loss: 0.32
# Validation Results - Epoch[212] Avg loss: 0.34
# Training Results - Epoch[213] Avg loss: 0.32
# Validation Results - Epoch[213] Avg loss: 0.34
# Training Results - Epoch[214] Avg loss: 0.32
# Validation Results - Epoch[214] Avg loss: 0.34
# Training Results - Epoch[215] Avg loss: 0.32
# Validation Results - Epoch[215] Avg loss: 0.34
# Training Results - Epoch[216] Avg loss: 0.32
# Validation Results - Epoch[216] Avg loss: 0.34
# Training Results - Epoch[217] Avg loss: 0.32
# Validation Results - Epoch[217] Avg loss: 0.34
# Training Results - Epoch[218] Avg loss: 0.32
# Validation Results - Epoch[218] Avg loss: 0.34
# Training Results - Epoch[219] Avg loss: 0.32
# Validation Results - Epoch[219] Avg loss: 0.34
# Training Results - Epoch[220] Avg loss: 0.32
# Validation Results - Epoch[220] Avg loss: 0.34
# Training Results - Epoch[221] Avg loss: 0.32
# Validation Results - Epoch[221] Avg loss: 0.34
# Training Results - Epoch[222] Avg loss: 0.32
# Validation Results - Epoch[222] Avg loss: 0.34
# Training Results - Epoch[223] Avg loss: 0.32
# Validation Results - Epoch[223] Avg loss: 0.34
# Training Results - Epoch[224] Avg loss: 0.32
# Validation Results - Epoch[224] Avg loss: 0.34
# Training Results - Epoch[225] Avg loss: 0.32
# Validation Results - Epoch[225] Avg loss: 0.34
# Training Results - Epoch[226] Avg loss: 0.32
# Validation Results - Epoch[226] Avg loss: 0.34
# Training Results - Epoch[227] Avg loss: 0.32
# Validation Results - Epoch[227] Avg loss: 0.34
# Training Results - Epoch[228] Avg loss: 0.32
# Validation Results - Epoch[228] Avg loss: 0.34
# Training Results - Epoch[229] Avg loss: 0.32
# Validation Results - Epoch[229] Avg loss: 0.34
# Training Results - Epoch[230] Avg loss: 0.32
# Validation Results - Epoch[230] Avg loss: 0.34
# Training Results - Epoch[231] Avg loss: 0.32
# Validation Results - Epoch[231] Avg loss: 0.34
# Training Results - Epoch[232] Avg loss: 0.32
# Validation Results - Epoch[232] Avg loss: 0.34
# Training Results - Epoch[233] Avg loss: 0.32
# Validation Results - Epoch[233] Avg loss: 0.34
# Training Results - Epoch[234] Avg loss: 0.32
# Validation Results - Epoch[234] Avg loss: 0.34
# Training Results - Epoch[235] Avg loss: 0.32
# Validation Results - Epoch[235] Avg loss: 0.34
# Training Results - Epoch[236] Avg loss: 0.32
# Validation Results - Epoch[236] Avg loss: 0.34
# Training Results - Epoch[237] Avg loss: 0.32
# Validation Results - Epoch[237] Avg loss: 0.34
# Training Results - Epoch[238] Avg loss: 0.32
# Validation Results - Epoch[238] Avg loss: 0.34
# Training Results - Epoch[239] Avg loss: 0.32
# Validation Results - Epoch[239] Avg loss: 0.34
# Training Results - Epoch[240] Avg loss: 0.32
# Validation Results - Epoch[240] Avg loss: 0.34
# Training Results - Epoch[241] Avg loss: 0.31
# Validation Results - Epoch[241] Avg loss: 0.34
# Training Results - Epoch[242] Avg loss: 0.32
# Validation Results - Epoch[242] Avg loss: 0.34
# Training Results - Epoch[243] Avg loss: 0.31
# Validation Results - Epoch[243] Avg loss: 0.34
# Training Results - Epoch[244] Avg loss: 0.31
# Validation Results - Epoch[244] Avg loss: 0.34
# Training Results - Epoch[245] Avg loss: 0.32
# Validation Results - Epoch[245] Avg loss: 0.34
# Training Results - Epoch[246] Avg loss: 0.31
# Validation Results - Epoch[246] Avg loss: 0.33
# Training Results - Epoch[247] Avg loss: 0.31
# Validation Results - Epoch[247] Avg loss: 0.34
# Training Results - Epoch[248] Avg loss: 0.31
# Validation Results - Epoch[248] Avg loss: 0.34
# Training Results - Epoch[249] Avg loss: 0.31
# Validation Results - Epoch[249] Avg loss: 0.33
# Training Results - Epoch[250] Avg loss: 0.31
# Validation Results - Epoch[250] Avg loss: 0.34
# Training Results - Epoch[251] Avg loss: 0.31
# Validation Results - Epoch[251] Avg loss: 0.34
# Training Results - Epoch[252] Avg loss: 0.31
# Validation Results - Epoch[252] Avg loss: 0.34
# Training Results - Epoch[253] Avg loss: 0.31
# Validation Results - Epoch[253] Avg loss: 0.34
# Training Results - Epoch[254] Avg loss: 0.31
# Validation Results - Epoch[254] Avg loss: 0.33
# Training Results - Epoch[255] Avg loss: 0.31
# Validation Results - Epoch[255] Avg loss: 0.34
# Training Results - Epoch[256] Avg loss: 0.31
# Validation Results - Epoch[256] Avg loss: 0.34
# Training Results - Epoch[257] Avg loss: 0.31
# Validation Results - Epoch[257] Avg loss: 0.33
# Training Results - Epoch[258] Avg loss: 0.31
# Validation Results - Epoch[258] Avg loss: 0.33
# Training Results - Epoch[259] Avg loss: 0.31
# Validation Results - Epoch[259] Avg loss: 0.34
# Training Results - Epoch[260] Avg loss: 0.31
# Validation Results - Epoch[260] Avg loss: 0.34
# Training Results - Epoch[261] Avg loss: 0.31
# Validation Results - Epoch[261] Avg loss: 0.34
# Training Results - Epoch[262] Avg loss: 0.31
# Validation Results - Epoch[262] Avg loss: 0.33
# Training Results - Epoch[263] Avg loss: 0.31
# Validation Results - Epoch[263] Avg loss: 0.34
# 2022-08-27 07:16:26,921 ignite.handlers.early_stopping.EarlyStopping INFO: EarlyStopping: Stop training
# Training Results - Epoch[264] Avg loss: 0.31
# Validation Results - Epoch[264] Avg loss: 0.33

# %%
train_res = 0.31
valid_res = 0.33
print(f'Train final results (after log transform) = {train_res}')
print(f'Train final results = {np.exp(train_res)}')
print(f'Valid final results (after log transform) = {valid_res}')
print(f'Valid final results = {np.exp(valid_res)}')
# Out:
# Train final results (after log transform) = 0.31
# Train final results = 1.3634251141321778
# Valid final results (after log transform) = 0.33
# Valid final results = 1.3909681284637803

# %% [markdown]
# ## Test

# %%
test_loss, df_test_preds = tester(
    model=model,
    dl_test=dl_test_exp,
    device=device
)
print(f'Test loss (after log transform) = {test_loss}')
print(f'Test loss = {np.exp(test_loss)}')
# Out:
# Test loss (after log transform) = 0.35949138297039746
# Test loss = 1.4326005841745495

# %%
df_test_preds['y_fixed'] = np.exp(df_test_preds['y'])
df_test_preds['y_pred_fixed'] = np.exp(df_test_preds['y_pred'])

y_col = 'y_fixed'
y_pred_col = 'y_pred_fixed'

df_test_preds['error'] = df_test_preds[y_col] - df_test_preds[y_pred_col]
df_test_preds.head()
# Out:
#    gene  spot         y    y_pred     y_fixed  y_pred_fixed      error
# 0    11  1166  3.737670  3.844644   42.000004     46.742033  -4.742030
# 1    20   794  4.262680  3.857095   71.000013     47.327653  23.672359
# 2    62    37  4.736198  4.521160  113.999997     91.942201  22.057797
# 3    10   687  3.178054  3.471697   24.000001     32.191320  -8.191319
# 4    11   318  3.465736  3.384500   32.000000     29.503224   2.496776

# %% [markdown]
# # Results Analysis

# %% [markdown]
# ## Errors Distribution

# %%
error_distribution(df_test_preds)
# Out:
# count    11376.000000
# mean         1.029692
# std         29.491817
# min       -586.891722
# 25%         -3.479503
# 50%          0.227684
# 75%          4.709984
# max        475.604979
# Name: error, dtype: float64

# %%
mask = df_test_preds['error'] > -1e5
error_distribution(df_test_preds, mask=mask)
# Out:
# count    11376.000000
# mean         1.029692
# std         29.491817
# min       -586.891722
# 25%         -3.479503
# 50%          0.227684
# 75%          4.709984
# max        475.604979
# Name: error, dtype: float64

# %% [markdown]
# ## Spots Errors Distribution

# %%
spots_error_distribution(df_test_preds)
# Out:
# count    1185.000000
# mean        0.931595
# std        11.479691
# min       -96.159350
# 25%        -1.660125
# 50%         0.781031
# 75%         3.640819
# max        79.139998
# Name: error, dtype: float64

# %% [markdown]
# ## Genes Errors Distribution

# %%
genes_error_distribution(df_test_preds)
# Out:
# count    96.000000
# mean      1.063710
# std       2.699911
# min     -10.829971
# 25%       0.248428
# 50%       0.625476
# 75%       1.330676
# max      13.929582
# Name: error, dtype: float64

# %% [markdown]
# ## Errors Heat Map

# %%
error_heat_map(df_test_preds, vmin=-700, vmax=700)
# Out:
# (1185, 96)

# %% [markdown]
# ## Reconstruction of the train matrix
# True expression values of the Train data
# - All Validation & Test vectors are changed to be 0

# %%
all_gens = []
all_spots = []
expressions_train = []
log_transform = True

for set_dl in [dl_train_exp, dl_valid_exp, dl_test_exp]:
    for batch in set_dl:
        gens, spots, y = batch
        gens.to(device)
        spots.to(device)
        
        if log_transform:
                y = torch.exp(y)

        all_gens.extend(gens.tolist())
        all_spots.extend(spots.tolist())
        if (set_dl == dl_valid_exp) or (set_dl == dl_test_exp):
            y_zeros = torch.zeros(size=y.shape)
            expressions_train.extend(y_zeros.tolist())
        else:
            expressions_train.extend(y.tolist())

# %%
df_expressions_train = pd.DataFrame({'gene': all_gens, 'spot': all_spots, 'expression': expressions_train})
df_expressions_train[['gene']] = oe_genes.inverse_transform(df_expressions_train[['gene']].values)
df_expressions_train[['spot']] = oe_spots.inverse_transform(df_expressions_train[['spot']].values)

# %%
df_expressions_train_matrix = df_expressions_train.pivot(index='spot', columns='gene', values='expression')

# %%
new_obj_train = deepcopy(obj)
tmp_genes_locations = [obj.var.index.get_loc(key=gene_key) for gene_key in df_expressions_train_matrix.columns]

# %%
# Replace the values
new_obj_train.X[:, tmp_genes_locations] = df_expressions_train_matrix.values
# Out:
# /usr/local/lib/python3.8/site-packages/scipy/sparse/_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)

# %% [markdown]
# ## Clustering The Train Dataset

# %%
st.pp.normalize_total(new_obj_train)
st.pp.log1p(new_obj_train)
# Out:
# Normalization step is finished in adata.X
# Log transformation step is finished in adata.X

# %%
# run PCA for gene expression data
st.em.run_pca(new_obj_train, n_comps=50)
# K-means clustering
st.tl.clustering.kmeans(new_obj_train, n_clusters=7, use_data="X_pca", key_added="X_pca_kmeans")
# Out:
# PCA is done! Generated in adata.obsm['X_pca'], adata.uns['pca'] and adata.varm['PCs']
# Applying Kmeans clustering ...
# Kmeans clustering is done! The labels are stored in adata.obs["kmeans"]

# %%
colors_map_dict = {
    '#1f77b4': 1, # Blue
    '#f87f13': 0, # Orange
    '#359c62': 3, # Green
    '#d32929': 4, # Red
    '#69308e': 5, # Purple
    '#8c564c': 6, # Brown
    '#f33ca9': 2  # Pink
}
clusters_colors = [c[0] for c in sorted(colors_map_dict.items(), key=lambda i: i[1])]

# %%
new_obj_train.uns['X_pca_kmeans_colors'] = clusters_colors

# %%
f = plt.figure()
st.pl.cluster_plot(new_obj_train, use_label="X_pca_kmeans")
plt.title('Train')
plt.show()

# %% [markdown]
# ## Reconstruction of the whole matrix

# %%
model = model.to(device)
model.eval()

all_gens = []
all_spots = []
expressions_pred = []
expressions_true = []
log_transform = True

with torch.no_grad():
    for set_dl in [dl_train_exp, dl_valid_exp, dl_test_exp]:
        for batch in set_dl:
            gens, spots, y = batch
            gens.to(device)
            spots.to(device)
            y_pred = model(gens, spots).to('cpu')
            
            if log_transform:
                y = torch.exp(y)
                y_pred = torch.exp(y_pred)
            
            y_pred = np.clip(a=y_pred, a_min=0, a_max=None)
                
            all_gens.extend(gens.tolist())
            all_spots.extend(spots.tolist())
            expressions_pred.extend(y_pred.tolist())
            expressions_true.extend(y.tolist())

# %%
df_expressions_preds = pd.DataFrame({'gene': all_gens, 'spot': all_spots, 'expression': expressions_pred})
df_expressions_preds[['gene']] = oe_genes.inverse_transform(df_expressions_preds[['gene']].values)
df_expressions_preds[['spot']] = oe_spots.inverse_transform(df_expressions_preds[['spot']].values)

# %%
df_expressions_true = df_expressions_preds.copy()
df_expressions_true['expression'] = expressions_true

# %%
df_expressions_preds_matrix = df_expressions_preds.pivot(index='spot', columns='gene', values='expression')
df_expressions_true_matrix = df_expressions_true.pivot(index='spot', columns='gene', values='expression')

# %%
f, (ax1, ax2) = plt.subplots(1, 2, figsize=(19, 6))
df_expressions_true.expression.hist(ax=ax1)
df_expressions_preds.expression.hist(ax=ax2)
ax1.set_title('True Genes Expression Histogram')
ax2.set_title('Prediction Genes Expression Histogram')
plt.show()

# %%
new_obj = deepcopy(obj)
tmp_genes_locations = [obj.var.index.get_loc(key=gene_key) for gene_key in df_expressions_true_matrix.columns]

# %%
# Replace the values
new_obj.X[:, tmp_genes_locations] = df_expressions_preds_matrix.values
# Out:
# /usr/local/lib/python3.8/site-packages/scipy/sparse/_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)

# %% [markdown]
# ## Clustering Full Reconstructed

# %%
new_obj_clusters = deepcopy(new_obj)

# %%
st.pp.normalize_total(new_obj_clusters)
st.pp.log1p(new_obj_clusters)
# Out:
# Normalization step is finished in adata.X
# Log transformation step is finished in adata.X

# %%
# run PCA for gene expression data
st.em.run_pca(new_obj_clusters, n_comps=50)
# K-means clustering
st.tl.clustering.kmeans(new_obj_clusters, n_clusters=7, use_data="X_pca", key_added="X_pca_kmeans")
# Out:
# PCA is done! Generated in adata.obsm['X_pca'], adata.uns['pca'] and adata.varm['PCs']
# Applying Kmeans clustering ...
# Kmeans clustering is done! The labels are stored in adata.obs["kmeans"]

# %%
colors_map_dict = {
    '#1f77b4': 1, # Blue
    '#f87f13': 0, # Orange
    '#359c62': 3, # Green
    '#d32929': 4, # Red
    '#69308e': 5, # Purple
    '#8c564c': 6, # Brown
    '#f33ca9': 2  # Pink
}
clusters_colors = [c[0] for c in sorted(colors_map_dict.items(), key=lambda i: i[1])]

# %%
new_obj_train.uns['X_pca_kmeans_colors'] = clusters_colors

# %%
f = plt.figure()
st.pl.cluster_plot(new_obj_clusters, use_label="X_pca_kmeans")
plt.title('Reconstructed')
# Out:
# Text(0.5, 1.0, 'Reconstructed')
